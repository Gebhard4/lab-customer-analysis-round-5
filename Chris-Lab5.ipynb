# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('C://Users/Ouroboros/lab-customer-analysis-round-5/files_for_lab/csv_files/marketing_customer_analysis.csv')
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
len(data)
# Out:
# 9134

# %%
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %%
y = data['Total Claim Amount']
X = data.drop(['Total Claim Amount'], axis=1)
X.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Last Claim Months Since Policy Inception  \
# 0                      32                             5
# ...

# %%
X_num = X.select_dtypes(include = np.number)
X_cat = X.select_dtypes(include = 'object')
X_num
# Out:
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
transformer = MinMaxScaler().fit(X_num) 
x_minmax = transformer.transform(X_num)
print(x_minmax.shape)
# Out:
# (9134, 7)

# %%
X_num_norm = pd.DataFrame(x_minmax,columns=X_num.columns)
X_num_norm.head()
# Out:
#    Customer Lifetime Value    Income  Monthly Premium Auto  \
# 0                 0.010629  0.562847              0.033755
# 1                 0.062406  0.000000              0.139241
# 2                 0.134960  0.487763              0.198312
# 3                 0.070589  0.000000              0.189873
# 4                 0.011245  0.438443              0.050633
#
#    Months Since Last Claim  Months Since Policy Inception  \
# 0                 0.914286                       0.050505
# 1                 0.371429                       0.424242
# 2                 0.514286                       0.383838
# 3                 0.514286                       0.656566
# 4                 0.342857                       0.444444
#
#    Number of Open Complaints  Number of Policies
# 0                        0.0               0.000
# 1                        0.0               0.875
# 2                        0.0               0.125
# 3                        0.0               0.750
# ...

# %%
X_num_norm.describe()
# Out:
#        Customer Lifetime Value       Income  Monthly Premium Auto  \
# count              9134.000000  9134.000000           9134.000000
# mean                  0.074999     0.376645              0.135946
# std                   0.084382     0.303857              0.145181
# min                   0.000000     0.000000              0.000000
# 25%                   0.025744     0.000000              0.029536
# 50%                   0.047677     0.338959              0.092827
# 75%                   0.086754     0.623318              0.202532
# max                   1.000000     1.000000              1.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                  0.431343                       0.485501
# std                   0.287807                       0.281879
# min                   0.000000                       0.000000
# ...
